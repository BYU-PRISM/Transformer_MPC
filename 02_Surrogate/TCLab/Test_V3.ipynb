# %%
import warnings

# with warnings.catch_warnings():
warnings.simplefilter("ignore")
warnings.filterwarnings("ignore")
from sklearn import preprocessing

from functions.process_fopdt import ProcessModel
from functions.mpc_nn import Mpc_nn

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go

from pickle import dump, load
from sklearn.preprocessing import MinMaxScaler
import time



# For LSTM model
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.models import load_model

import tclab

# Load NN model parameters and MinMaxScaler
model_params = load(open('model_param_MIMO.pkl', 'rb'))
s1 = model_params['Xscale']
print(s1)
s2 = model_params['yscale']
print(s2)
window = model_params['window']

# Load NN models (onestep prediction models)
model_lstm_one = load_model('MPC_MIMO_TCLab_onestep_LSTM.h5')
model_trans_one = load_model('MPC_MIMO_TCLab_onestep_Trans.h5')

# Load NN models (multistep prediction models)
model_lstm_multi = load_model('MPC_MIMO_TCLab_multistep_LSTM.h5')
model_trans_multi = load_model('MPC_MIMO_TCLab_multistep_Trans.h5')

# # FOPDT Parameters
# K=1.0      # gain
# tau=2.0    # time constant
ns = 15*60  # Simulation Length
t = np.linspace(0, ns, ns + 1)
delta_t = t[1] - t[0]

nu = 2
ny = 2

# Define horizons
P = 10  # Prediction Horizon
M = 4  # Control Horizon

# Input Sequence
u = np.zeros((ns + 1, nu))
# u[5:,0] = .3
# u[5:,1] = .6

## Set initial temp - both T1 and T2??
T1_set = 35
T2_set = 30

# Setpoint Sequence

sp1 = np.zeros(ns + 1)
sp1 = sp1+T1_set
# sp1[80:] = 1.5

sp2 = np.zeros(ns + 1)
sp2 = sp2+T2_set
# sp2[80:] = 1.5

sp = np.array([sp1, sp2]).T
target = np.array([T1_set,T2_set]).T

# Controller setting
maxmove = 1

# Process simulation
yp = np.zeros((ns + 1, ny))
yp_nn = np.zeros((ns + 1, ny, P))








# p = ProcessModel(delta_t)
m = Mpc_nn(window, nu, ny, P, M, s1, s2, multistep=0, model_one=model_trans_one, model_multi=model_trans_multi)
# multistep = 0 : sequential onestep prediction MPC
# multistep = 1 : simultaneous multistep prediction MPC


print(window)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23276\1729036154.py in <cell line: 8>()
#       6 from sklearn import preprocessing
#       7
# ----> 8 from functions.process_fopdt import ProcessModel
#       9 from functions.mpc_nn import Mpc_nn
#      10
#
# ModuleNotFoundError: No module named 'functions.process_fopdt'; 'functions' is not a package

# %%
# the control interval in seconds
CI = 30

T1_arr = np.zeros((P*60))
T2_arr = np.zeros((P*60))
Q1_arr = np.zeros((P*60))
Q2_arr = np.zeros((P*60))





tsim = 15*60 # time in sec




## Get initial data
#uhat = np.zeros((M, nu))



lab = tclab.TCLab()


for i in range(len(T1_arr)):
    t_in = time.time()
    T1_arr[i] = lab.T1
    T2_arr[i] = lab.T2
    Q1_arr[i] = lab.Q1()
    Q2_arr[i] = lab.Q2()
    if(T1_arr[i] < T1_set):
        lab.Q1(80)
    else:
        lab.Q1(0)
    if(T2_arr[i] < T2_set):
        lab.Q2(80)
    else:
        lab.Q2(0)
        
    print(T1_arr[i], Q1_arr[i])
    

    t_out = time.time()
    time.sleep(1-(t_out-t_in))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23276\3740750265.py in <cell line: 4>()
#       2 CI = 30
#       3
# ----> 4 T1_arr = np.zeros((P*60))
#       5 T2_arr = np.zeros((P*60))
#       6 Q1_arr = np.zeros((P*60))
#
# NameError: name 'np' is not defined

# %%
import pickle


print (T1_arr, Q1_arr)
print (T2_arr, Q2_arr)


# Read data file
tcL_data1 = pd.DataFrame(
        {"H1": Q1_arr,
         "H2": Q2_arr,
         "T1": T1_arr,
         "T2": T2_arr},
        index = np.linspace(1,P*60+1,P*60+1,dtype=int))

tcL_data1.to_pickle('Test1.pkl')



tcLab = pd.read_pickle('Test1.pkl') # Put the original na


tcLab
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23276\1219797220.py in <cell line: 4>()
#       2
#       3
# ----> 4 print (T1_arr, Q1_arr)
#       5 print (T2_arr, Q2_arr)
#       6
#
# NameError: name 'T1_arr' is not defined

# %%
uhat = np.zeros((M,nu))
for i in range(tsim):
    t_in = time.time()
    T1 = lab.T1
    T2 = lab.T2
    Q1 = lab.Q1()
    Q2 = lab.Q2()

    T1_arr = np.append(T1_arr,T1)
    T2_arr = np.append(T2_arr,T2)
    Q1_arr = np.append(Q1_arr,Q1)
    Q2_arr = np.append(Q2_arr,Q2)

    u = np.vstack((Q1_arr,Q2_arr)).T
    y = np.vstack((T1_arr,T2_arr)).T
    target = np.array([T1_set,T2_set]).T
    
    
    if i%30 == 0:
        
        u_window = u[-60*P::30]
        y_window = y[-60*P::30]
        
        
        #uhat = m.run(uhat, u_window, y_window, target)
        uhat = m.run(uhat, u_window, y_window, sp[i])

        lab.Q1(uhat[0][0])
        lab.Q2(uhat[1][0])

    t_out = time.time()
    time.sleep(1-(t_out-t_in))



# plt.plot(t, yp)
plt.subplot(2, 1, 1)
plt.plot(t, y[:, 0])
plt.plot(t, y[:, 1])
# plt.plot(t, yp_nn[:, :, 0], '-.')
plt.step(t, sp[:, 0])
plt.step(t, sp[:, 1])
plt.subplot(2, 1, 2)
plt.step(t, u[:, 0])
plt.step(t, u[:, 1])
plt.show()

print("break point")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23276\3608817330.py in <cell line: 1>()
# ----> 1 uhat = np.zeros((M,nu))
#       2 for i in range(tsim):
#       3     t_in = time.time()
#       4     T1 = lab.T1
#       5     T2 = lab.T2
#
# NameError: name 'np' is not defined

# %%
import sys

print(sys.path)
# Out:
# ['C:\\Users\\HAN\\Documents\\GitHub\\Transformer_MPC\\02_Surrogate\\TCLab', 'C:\\Program Files\\PerkinElmerInformatics\\ChemOffice2019\\ChemScript\\Lib', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310\\DLLs', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310', '', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\Pythonwin', 'C:\\Users\\HAN\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\HAN\\.ipython']
